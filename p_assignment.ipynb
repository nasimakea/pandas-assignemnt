# %% [markdown]
# ## Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# ## ANS:-

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.shape
# Out:
# (3000, 9)

# %%
def square(x):
  return x**2

# %%
df.apply(square,axis=1)
# Out:
#        longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     14896.2025  1396.5169               729.0   15093225.0        436921.0
# 1     13994.8900  1173.7476              1849.0    2280100.0         96100.0
# 2     13879.1961  1141.0884               729.0   12880921.0        257049.0
# 3     14009.0896  1143.7924               784.0       4489.0           225.0
# 4     14320.9089  1319.8689               361.0    1540081.0         59536.0
# ...          ...        ...                 ...          ...             ...
# 2995  14366.4196  1184.7364               529.0    2102500.0        412164.0
# 2996  13957.0596  1160.0836               729.0   27636049.0       1170724.0
# 2997  14328.0900  1317.6900               100.0     913936.0         40401.0
# 2998  13717.0944  1162.8100              1600.0       9216.0           196.0
# 2999  14311.3369  1184.7364              1764.0    3115225.0         69169.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.drop('longitude',axis=1)
# Out:
#       latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        37.37                27.0       3885.0           661.0      1537.0
# 1        34.26                43.0       1510.0           310.0       809.0
# 2        33.78                27.0       3589.0           507.0      1484.0
# 3        33.82                28.0         67.0            15.0        49.0
# 4        36.33                19.0       1241.0           244.0       850.0
# ...        ...                 ...          ...             ...         ...
# 2995     34.42                23.0       1450.0           642.0      1258.0
# 2996     34.06                27.0       5257.0          1082.0      3496.0
# 2997     36.30                10.0        956.0           201.0       693.0
# 2998     34.10                40.0         96.0            14.0        46.0
# 2999     34.42                42.0       1765.0           263.0       753.0
#
#       households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# ## Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data={'A':[12,23,34,45,56],'B':[23,34,54,56,78],'C':[23,45,67,89,54]}

# %%
df=pd.DataFrame(data)

# %%
new_index=[1,2,3]

# %%
df.columns=new_index

# %%
df
# Out:
#     1   2   3
# 0  12  23  23
# 1  23  34  45
# 2  34  54  67
# 3  45  56  89
# 4  56  78  54

# %% [markdown]
# ## Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df['Values']=df['longitude']

# %%
df['Values']=df['Values'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
#  9   Values              3000 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 234.5 KB

# %%
sum_to_3_index=df['Values'].iloc[:3].sum()

# %%
print(sum_to_3_index)
# Out:
# -357

# %%
df['Values'].head(3)
# Out:
# 0   -122
# 1   -118
# 2   -117
# Name: Values, dtype: int64

# %% [markdown]
# ## Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.
#
#
#
#
# ## ANS:-

# %%
data={"text":['nasim','khan','repect','MY country','bihar','data science']}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#          text
# 0       nasim
# 1        khan
# 2      repect
# 3  MY country
# 4       bihar

# %%
Word_Count=[]
for i in df['text']:
  if type(i)==str:
    Word_Count.append(len(i))

# %%
  Word_Count
# Out:
# [5, 4, 6, 10, 5, 12]

# %%
df['Word_Count']=pd.DataFrame({'Word_Count':Word_Count})

# %%
df.head()
# Out:
#          text  Word_Count
# 0       nasim           5
# 1        khan           4
# 2      repect           6
# 3  MY country          10
# 4       bihar           5

# %% [markdown]
# ## Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# ## ANS:- Let's understand with the help of above data used in the previous questions

# %%
df.size
# Out:
# 12

# %% [markdown]
# the DataFrame.size is not the function but instance , it helps in calculationg number of data present in all the columns

# %%
df.shape
# Out:
# (6, 2)

# %% [markdown]
# ## Where as the DataFrame.shape() is aslo the instance which gives the number of rows and columns in a DataFrame

# %% [markdown]
# ## Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# ## ANS :- We already have imported pandas in the previous question , we just have to import an excel from our system

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/FSI-2023-DOWNLOAD.xlsx")

# %%
df.head()
# Out:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 0                    Somalia  2023  1st  111.9                       10.0
# 1                      Yemen  2023  2nd  108.9                        9.6
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 0                    9.0                  8.7
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 0                               8.6                      9.1          9.5
# 1                               6.4                      7.9          9.9
# ...

# %% [markdown]
# ## Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
#
# ## The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %% [markdown]
# ## ANS:-  Let's first make a datafram which contain emails only

# %%
data={'Email':['nasimakram6200@gmail.com','aasimakram6200@gmail.com','zasimakram6200@gmail.com','basimakram6200@gmail.com','dasimakram6200@gmail.com','rasimakram6200@gmail.com']}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                       Email
# 0  nasimakram6200@gmail.com
# 1  aasimakram6200@gmail.com
# 2  zasimakram6200@gmail.com
# 3  basimakram6200@gmail.com
# 4  dasimakram6200@gmail.com

# %%
df['Username'] = df['Email'].str.split('@').str.get(0)

# %%
df.head()
# Out:
#                       Email        Username
# 0  nasimakram6200@gmail.com  nasimakram6200
# 1  aasimakram6200@gmail.com  aasimakram6200
# 2  zasimakram6200@gmail.com  zasimakram6200
# 3  basimakram6200@gmail.com  basimakram6200
# 4  dasimakram6200@gmail.com  dasimakram6200

# %% [markdown]
# ## Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.For example, if df contains the following values:
# A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
#
#
# Your function should select the following rows: A B C
# 1 8 2 7
# 4 9 1 2
# The function should return a new DataFrame that contains only the selected rows.

# %% [markdown]
# ##ANS:- Lst's Create a DataFrame as per the given example

# %%
data={'A':[3,8,6,2,9],'B':[5,2,9,3,1],'C':[1,7,4,5,2]}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return selected_rows

# %%
select_rows(df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# ## Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean, median, and standard deviation of the values in the 'Values' column.
#
#
#
#
#
#
#
#
#
# ## ANS:-

# %%
data={"Values":[123,34,566,54,34,56,78,65,45,34,45,677,56,78,987,56,456,234,23,456,123,421]}

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(data)

# %%
np.mean(df['Values'])
# Out:
# 213.6818181818182

# %%
np.median(df['Values'])
# Out:
# 71.5

# %%
np.std(df['Values'])
# Out:
# 257.89592445643586

# %% [markdown]
# ## Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %% [markdown]
# ## ANS:-

# %%
 df = pd.DataFrame({'Date': ['2022-01-20', '2022-01-21', '2022-01-21', '2022-01-22', '2022-01-23', '20222-01-24', '2022-01-25'],
                   'Sales': [10, 12, 15, 18, 20, 22, 25]})

# %%
df
# Out:
#           Date  Sales
# 0   2022-01-20     10
# 1   2022-01-21     12
# 2   2022-01-21     15
# 3   2022-01-22     18
# 4   2022-01-23     20
# 5  20222-01-24     22
# 6   2022-01-25     25

# %% [markdown]
# # Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# #column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# #Monday, Tuesday) corresponding to each date in the 'Date' column.
# #For example, if df contains the following values:
# #Date
# #0 2023-01-01
# #1 2023-01-02
# #2 2023-01-03
# #3 2023-01-04
# #4 2023-01-05
# #Your function should create the following DataFrame:
#
# #Date Weekday
# #0 2023-01-01 Sunday
# #1 2023-01-02 Monday
# #2 2023-01-03 Tuesday
# #3 2023-01-04 Wednesday
# #4 2023-01-05 Thursday
# #The function should return the modified DataFrame.
